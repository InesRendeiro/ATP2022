# %%
import random
def menu():
    print('''qual vai ser o operação? 
(0)sair, 
(1)criar Lista, 
(2)le lista, 
(3)soma, 
(4)média, 
(5)maior, 
(6)menor,
(7)Ordem crescente, 
(8)Ordem decrescente,
(9)procurar elem''')
    return
def criarLista(tamanho):
    lista=[]
    i=0
    while i<tamanho:
        elem=random.randint(1,100)
        lista.append(elem)
        i=i+1
    return lista

def leLista(N):
    listaN=[]
    n=0
    while N>0:
        n=int(input("insira o numero"))
        listaN.append(n)
        N=N-1
    return listaN

def somaLista(lista):
    soma=0
    for i in lista:
        soma=soma+i
    return soma

def mediaLista(lista):
    total=0
    soma=0
    for i in lista:
        soma=soma+i
        total=total+1
    média=soma/total
    return média 

def maiorLista(lista):
    maior=lista[0]
    for i in lista:
        if i>maior:
            maior=i
    return maior 

def menorLista(lista):
    menor=lista[0]
    for i in lista:
        if i<menor:
            menor=i
    return menor

def crescenteLista(lista):
    valor=True
    i=0
    while i+1<len(lista):
        if lista[i]>lista[i+1]:
            valor=False
        i=i+1
    return valor

def decrescenteLista(lista):
    valor=True
    i=0
    while i+1<len(lista):
        if lista[i]<lista[i+1]:
            valor=False
        i=i+1
    return valor

def pos(lista, elem):
    posLista=[]
    for i in range(len(lista)):
        if lista[i]==elem:
            posLista.append(i+1)
    if len(posLista)==0:
        posLista.append(-1)
    return posLista 

menu()
função=int(input("qual vai ser a função que quer?"))
res=[]

while função!=0:
    if função==1:
        res.clear()
        res=criarListaRand(int(input("Qual o tamanho da lista?")))
    if função==2:
        res.clear()
        res=criarLista(int(input("Qual o tamanho da lista?")))
    if função==3:
        print("")
        print("A soma  da sua lista é:",somaLista(res))
    if função==4:
        print("")
        print("A média  da sua lista é:",mediaLista(res))
    if função==5:
        print("")
        print("O maior elemento da sua lista é:",maiorLista(res))
    if função==6:
        print("")
        print("O menor elemento da sua lista é:",menorLista(res))
    if função==7:
        if crescenteLista(res)==True:
            print("")
            print("Sim.")
        else:
            print("")
            print("Não.")
    if função==8:
        if decrescenteLista(res)==True:
            print("")
            print("Sim.")
        else:
            print("")
            print("Não.")
    if função==9:
        posLista=pos(res,int(input("Qual o elemento que procura?")))
        if posLista[0]==-1:
            print("")
            print("O elemento não se encontra na lista.")
        else:
            print("")
            print("O elemento encontra-se na(s)",posLista,"posição(ões).")
    função=int(input("O que pretende fazer?"))
print("")
print("A sua lista é:", res)
